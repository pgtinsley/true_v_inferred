# %%
import pickle

# %%
f1 = open('true_face_haar.pickle', 'rb')
f2 = open('inferred_face_haar.pickle', 'rb')

# %%
true_dict = pickle.load(f1)
inferred_dict = pickle.load(f2)

# %%
inferred_dict
# Out:
# {1: {'coords_list': [],
#   'sec': 0.5722894668579102,
#   'found_body': True,
#   'found_face': False},
#  2: {'coords_list': [],
#   'sec': 0.1628260612487793,
#   'found_body': True,
#   'found_face': False},
#  3: {'coords_list': [],
#   'sec': 0.16962313652038574,
#   'found_body': True,
#   'found_face': False},
#  4: {'coords_list': [],
#   'sec': 0.1744687557220459,
#   'found_body': True,
#   'found_face': False},
#  5: {'coords_list': [],
#   'sec': 0.1569664478302002,
#   'found_body': True,
#   'found_face': False},
#  6: {'coords_list': [],
#   'sec': 0.15444421768188477,
#   'found_body': True,
#   'found_face': False},
#  7: {'coords_list': [],
#   'sec': 0.1496114730834961,
#   'found_body': True,
#   'found_face': False},
#  8: {'coords_list': [],
#   'sec': 0.1564490795135498,
#   'found_body': True,
#   'found_face': False},
#  9: {'coords_list': [],
#   'sec': 0.15852022171020508,
#   'found_body': True,
#   'found_face': False},
#  10: {'coords_list': [],
#   'sec': 0.1425766944885254,
#   'found_body': True,
#   'found_face': False},
#  11: {'coords_list': [],
#   'sec': 0.15416407585144043,
#   'found_body': True,
#   'found_face': False},
#  12: {'coords_list': [],
#   'sec': 0.13618850708007812,
#   'found_body': True,
#   'found_face': False},
#  13: {'coords_list': [],
#   'sec': 0.15871906280517578,
#   'found_body': True,
#   'found_face': False},
#  14: {'coords_list': [],
#   'sec': 0.14708662033081055,
#   'found_body': True,
#   'found_face': False},
#  15: {'coords_list': [],
#   'sec': 0.15310883522033691,
#   'found_body': True,
#   'found_face': False},
#  16: {'coords_list': [],
#   'sec': 0.14581608772277832,
#   'found_body': True,
#   'found_face': False},
#  17: {'coords_list': [],
#   'sec': 0.1456773281097412,
#   'found_body': False,
#   'found_face': False},
#  18: {'coords_list': [],
#   'sec': 0.13575363159179688,
#   'found_body': False,
#   'found_face': False},
#  19: {'coords_list': [],
#   'sec': 0.13921499252319336,
#   'found_body': False,
#   'found_face': False},
#  20: {'coords_list': [],
#   'sec': 0.15152955055236816,
#   'found_body': False,
#   'found_face': False},
#  21: {'coords_list': [],
#   'sec': 0.142913818359375,
#   'found_body': False,
#   'found_face': False},
#  22: {'coords_list': [],
#   'sec': 0.14591050148010254,
#   'found_body': False,
#   'found_face': False},
#  23: {'coords_list': [],
#   'sec': 0.14428091049194336,
#   'found_body': False,
#   'found_face': False},
#  24: {'coords_list': [],
#   'sec': 0.14328384399414062,
#   'found_body': False,
#   'found_face': False},
#  25: {'coords_list': [],
#   'sec': 0.14797282218933105,
#   'found_body': False,
#   'found_face': False},
#  26: {'coords_list': [],
#   'sec': 0.1377546787261963,
#   'found_body': False,
#   'found_face': False},
#  27: {'coords_list': [],
#   'sec': 0.1219325065612793,
#   'found_body': False,
#   'found_face': False},
#  28: {'coords_list': [],
#   'sec': 0.11293601989746094,
#   'found_body': False,
#   'found_face': False},
#  29: {'coords_list': [],
#   'sec': 0.11761164665222168,
#   'found_body': False,
#   'found_face': False},
#  30: {'coords_list': [],
#   'sec': 0.11949324607849121,
#   'found_body': False,
#   'found_face': False},
#  31: {'coords_list': [],
#   'sec': 0.14120244979858398,
#   'found_body': False,
#   'found_face': False},
#  32: {'coords_list': [],
#   'sec': 0.13782668113708496,
#   'found_body': False,
#   'found_face': False},
#  33: {'coords_list': [],
#   'sec': 0.1374070644378662,
#   'found_body': False,
#   'found_face': False},
#  34: {'coords_list': [],
#   'sec': 0.13367104530334473,
#   'found_body': False,
#   'found_face': False},
#  35: {'coords_list': [],
#   'sec': 0.12452101707458496,
#   'found_body': False,
#   'found_face': False},
#  36: {'coords_list': [],
#   'sec': 0.11518573760986328,
#   'found_body': False,
#   'found_face': False},
#  37: {'coords_list': [],
#   'sec': 0.13366317749023438,
#   'found_body': False,
#   'found_face': False},
#  38: {'coords_list': [],
#   'sec': 0.11934423446655273,
#   'found_body': False,
#   'found_face': False},
#  39: {'coords_list': [],
#   'sec': 0.11351418495178223,
#   'found_body': False,
#   'found_face': False},
#  40: {'coords_list': [],
#   'sec': 0.11661553382873535,
#   'found_body': False,
#   'found_face': False},
#  41: {'coords_list': [],
#   'sec': 0.11664915084838867,
#   'found_body': False,
#   'found_face': False},
#  42: {'coords_list': [],
#   'sec': 0.11450576782226562,
#   'found_body': False,
#   'found_face': False},
#  43: {'coords_list': [],
#   'sec': 0.11443829536437988,
#   'found_body': False,
#   'found_face': False},
#  44: {'coords_list': [],
#   'sec': 0.11812162399291992,
#   'found_body': False,
#   'found_face': False},
#  45: {'coords_list': [],
#   'sec': 0.12316751480102539,
#   'found_body': False,
#   'found_face': False},
#  46: {'coords_list': [],
#   'sec': 0.11340737342834473,
#   'found_body': False,
#   'found_face': False},
#  47: {'coords_list': [],
#   'sec': 0.12077522277832031,
#   'found_body': False,
#   'found_face': False},
#  48: {'coords_list': [],
#   'sec': 0.11457681655883789,
#   'found_body': False,
#   'found_face': False},
#  49: {'coords_list': [],
#   'sec': 0.12503957748413086,
#   'found_body': False,
#   'found_face': False},
#  50: {'coords_list': [],
#   'sec': 0.13451457023620605,
#   'found_body': False,
#   'found_face': False},
#  51: {'coords_list': [],
#   'sec': 0.13995885848999023,
#   'found_body': False,
#   'found_face': False},
#  52: {'coords_list': [],
#   'sec': 0.13396787643432617,
#   'found_body': False,
#   'found_face': False},
#  53: {'coords_list': [],
#   'sec': 0.1346735954284668,
#   'found_body': False,
#   'found_face': False},
#  54: {'coords_list': [],
#   'sec': 0.13259124755859375,
#   'found_body': False,
#   'found_face': False},
#  55: {'coords_list': [],
#   'sec': 0.1503911018371582,
#   'found_body': False,
#   'found_face': False},
#  56: {'coords_list': [],
#   'sec': 0.1748960018157959,
#   'found_body': False,
#   'found_face': False},
#  57: {'coords_list': [],
#   'sec': 0.14962077140808105,
#   'found_body': False,
#   'found_face': False},
#  58: {'coords_list': [],
#   'sec': 0.13668394088745117,
#   'found_body': False,
#   'found_face': False},
#  59: {'coords_list': [],
#   'sec': 0.1394491195678711,
#   'found_body': False,
#   'found_face': False},
#  60: {'coords_list': [],
#   'sec': 0.12148761749267578,
#   'found_body': False,
#   'found_face': False},
#  61: {'coords_list': [],
#   'sec': 0.11658525466918945,
#   'found_body': False,
#   'found_face': False},
#  62: {'coords_list': [],
#   'sec': 0.11241722106933594,
#   'found_body': False,
#   'found_face': False},
#  63: {'coords_list': [],
#   'sec': 0.12508130073547363,
#   'found_body': False,
#   'found_face': False},
#  64: {'coords_list': [],
#   'sec': 0.11497616767883301,
#   'found_body': False,
#   'found_face': False},
#  65: {'coords_list': [],
#   'sec': 0.12235641479492188,
#   'found_body': False,
#   'found_face': False},
#  66: {'coords_list': [],
#   'sec': 0.12697601318359375,
#   'found_body': False,
#   'found_face': False},
#  67: {'coords_list': [],
#   'sec': 0.13483023643493652,
#   'found_body': False,
#   'found_face': False},
#  68: {'coords_list': [],
#   'sec': 0.13251614570617676,
#   'found_body': True,
#   'found_face': False},
#  69: {'coords_list': [],
#   'sec': 0.12432694435119629,
#   'found_body': False,
#   'found_face': False},
#  70: {'coords_list': [],
#   'sec': 0.11306524276733398,
#   'found_body': False,
#   'found_face': False},
#  71: {'coords_list': [],
#   'sec': 0.11847496032714844,
#   'found_body': False,
#   'found_face': False},
#  72: {'coords_list': [],
#   'sec': 0.11858105659484863,
#   'found_body': False,
#   'found_face': False},
#  73: {'coords_list': [],
#   'sec': 0.11355376243591309,
#   'found_body': False,
#   'found_face': False},
#  74: {'coords_list': [],
#   'sec': 0.11200118064880371,
#   'found_body': False,
#   'found_face': False},
#  75: {'coords_list': [],
#   'sec': 0.1159210205078125,
#   'found_body': True,
#   'found_face': False},
#  76: {'coords_list': [],
#   'sec': 0.12232542037963867,
#   'found_body': True,
#   'found_face': False},
#  77: {'coords_list': [],
#   'sec': 0.11618590354919434,
#   'found_body': True,
#   'found_face': False},
#  78: {'coords_list': [],
#   'sec': 0.12467789649963379,
#   'found_body': False,
#   'found_face': False},
#  79: {'coords_list': [],
#   'sec': 0.1302201747894287,
#   'found_body': False,
#   'found_face': False},
#  80: {'coords_list': [],
#   'sec': 0.1346588134765625,
#   'found_body': False,
#   'found_face': False},
#  81: {'coords_list': [],
#   'sec': 0.15953922271728516,
#   'found_body': False,
#   'found_face': False},
#  82: {'coords_list': [],
#   'sec': 0.13729023933410645,
#   'found_body': False,
#   'found_face': False},
#  83: {'coords_list': [],
#   'sec': 0.1258845329284668,
#   'found_body': False,
#   'found_face': False},
#  84: {'coords_list': [],
#   'sec': 0.11619138717651367,
#   'found_body': False,
#   'found_face': False},
#  85: {'coords_list': [],
#   'sec': 0.13261866569519043,
#   'found_body': False,
#   'found_face': False},
#  86: {'coords_list': [],
#   'sec': 0.11668777465820312,
#   'found_body': False,
#   'found_face': False},
#  87: {'coords_list': [],
#   'sec': 0.11835932731628418,
#   'found_body': False,
#   'found_face': False},
#  88: {'coords_list': [],
#   'sec': 0.14527273178100586,
#   'found_body': False,
#   'found_face': False},
#  89: {'coords_list': [],
#   'sec': 0.14574432373046875,
#   'found_body': False,
#   'found_face': False},
#  90: {'coords_list': [],
#   'sec': 0.1531212329864502,
#   'found_body': True,
#   'found_face': False},
#  91: {'coords_list': [],
#   'sec': 0.14776015281677246,
#   'found_body': True,
#   'found_face': False},
#  92: {'coords_list': [],
#   'sec': 0.1382615566253662,
#   'found_body': False,
#   'found_face': False},
#  93: {'coords_list': [],
#   'sec': 0.13980865478515625,
#   'found_body': False,
#   'found_face': False},
#  94: {'coords_list': [],
#   'sec': 0.13593125343322754,
#   'found_body': False,
#   'found_face': False},
#  95: {'coords_list': [],
#   'sec': 0.12717199325561523,
#   'found_body': False,
#   'found_face': False},
#  96: {'coords_list': [],
#   'sec': 0.12071561813354492,
#   'found_body': False,
#   'found_face': False},
#  97: {'coords_list': [],
#   'sec': 0.11917233467102051,
#   'found_body': False,
#   'found_face': False},
#  98: {'coords_list': [],
#   'sec': 0.11824226379394531,
#   'found_body': False,
#   'found_face': False},
#  99: {'coords_list': [],
#   'sec': 0.11506032943725586,
#   'found_body': False,
#   'found_face': False},
#  100: {'coords_list': [],
#   'sec': 0.11923098564147949,
#   'found_body': False,
#   'found_face': False},
#  101: {'coords_list': [],
#   'sec': 0.11783838272094727,
#   'found_body': False,
#   'found_face': False},
#  102: {'coords_list': [],
#   'sec': 0.11711716651916504,
#   'found_body': False,
#   'found_face': False},
#  103: {'coords_list': [],
#   'sec': 0.13932037353515625,
#   'found_body': False,
#   'found_face': False},
#  104: {'coords_list': [],
#   'sec': 0.13494253158569336,
#   'found_body': False,
#   'found_face': False},
#  105: {'coords_list': [],
#   'sec': 0.13777494430541992,
#   'found_body': False,
#   'found_face': False},
#  106: {'coords_list': [],
#   'sec': 0.13130950927734375,
#   'found_body': False,
#   'found_face': False},
#  107: {'coords_list': [],
#   'sec': 0.12892889976501465,
#   'found_body': False,
#   'found_face': False},
#  108: {'coords_list': [],
#   'sec': 0.13092279434204102,
#   'found_body': False,
#   'found_face': False},
#  109: {'coords_list': [],
#   'sec': 0.11542224884033203,
#   'found_body': False,
#   'found_face': False},
#  110: {'coords_list': [],
#   'sec': 0.12762856483459473,
#   'found_body': True,
#   'found_face': False},
#  111: {'coords_list': [],
#   'sec': 0.12136030197143555,
#   'found_body': True,
#   'found_face': False},
#  112: {'coords_list': [],
#   'sec': 0.12389421463012695,
#   'found_body': False,
#   'found_face': False},
#  113: {'coords_list': [],
#   'sec': 0.12283015251159668,
#   'found_body': False,
#   'found_face': False},
#  114: {'coords_list': [],
#   'sec': 0.1240234375,
#   'found_body': True,
#   'found_face': False},
#  115: {'coords_list': [],
#   'sec': 0.12270116806030273,
#   'found_body': True,
#   'found_face': False},
#  116: {'coords_list': [],
#   'sec': 0.146162748336792,
#   'found_body': False,
#   'found_face': False},
#  117: {'coords_list': [],
#   'sec': 0.13741731643676758,
#   'found_body': False,
#   'found_face': False},
#  118: {'coords_list': [],
#   'sec': 0.14858555793762207,
#   'found_body': True,
#   'found_face': False},
#  119: {'coords_list': [],
#   'sec': 0.14536142349243164,
#   'found_body': True,
#   'found_face': False},
#  120: {'coords_list': [],
#   'sec': 0.1381053924560547,
#   'found_body': True,
#   'found_face': False},
#  121: {'coords_list': [],
#   'sec': 0.1548597812652588,
#   'found_body': True,
#   'found_face': False},
#  122: {'coords_list': [],
#   'sec': 0.14146137237548828,
#   'found_body': False,
#   'found_face': False},
#  123: {'coords_list': [],
#   'sec': 0.1356666088104248,
#   'found_body': False,
#   'found_face': False},
#  124: {'coords_list': [],
#   'sec': 0.14489269256591797,
#   'found_body': False,
#   'found_face': False},
#  125: {'coords_list': [],
#   'sec': 0.15748071670532227,
#   'found_body': True,
#   'found_face': False},
#  126: {'coords_list': [],
#   'sec': 0.14227032661437988,
#   'found_body': True,
#   'found_face': False},
#  127: {'coords_list': [],
#   'sec': 0.1293342113494873,
#   'found_body': True,
#   'found_face': False},
#  128: {'coords_list': [],
#   'sec': 0.14589476585388184,
#   'found_body': True,
#   'found_face': False},
#  129: {'coords_list': [],
#   'sec': 0.12446117401123047,
#   'found_body': True,
#   'found_face': False},
#  130: {'coords_list': [],
#   'sec': 0.12155508995056152,
#   'found_body': True,
#   'found_face': False},
#  131: {'coords_list': [],
#   'sec': 0.15460872650146484,
#   'found_body': True,
#   'found_face': False},
#  132: {'coords_list': [],
#   'sec': 0.15624070167541504,
#   'found_body': True,
#   'found_face': False},
#  133: {'coords_list': [],
#   'sec': 0.12356710433959961,
#   'found_body': True,
#   'found_face': False},
#  134: {'coords_list': [],
#   'sec': 0.14230561256408691,
#   'found_body': True,
#   'found_face': False},
#  135: {'coords_list': [],
#   'sec': 0.12254118919372559,
#   'found_body': True,
#   'found_face': False},
#  136: {'coords_list': [],
#   'sec': 0.11960935592651367,
#   'found_body': True,
#   'found_face': False},
#  137: {'coords_list': [],
#   'sec': 0.11987972259521484,
#   'found_body': True,
#   'found_face': False},
#  138: {'coords_list': [],
#   'sec': 0.13227009773254395,
#   'found_body': True,
#   'found_face': False},
#  139: {'coords_list': [],
#   'sec': 0.13088154792785645,
#   'found_body': True,
#   'found_face': False},
#  140: {'coords_list': [],
#   'sec': 0.12624025344848633,
#   'found_body': True,
#   'found_face': False},
#  141: {'coords_list': [],
#   'sec': 0.11706805229187012,
#   'found_body': True,
#   'found_face': False},
#  142: {'coords_list': [],
#   'sec': 0.11882948875427246,
#   'found_body': True,
#   'found_face': False},
#  143: {'coords_list': [],
#   'sec': 0.12191653251647949,
#   'found_body': True,
#   'found_face': False},
#  144: {'coords_list': [],
#   'sec': 0.13719892501831055,
#   'found_body': True,
#   'found_face': False},
#  145: {'coords_list': [],
#   'sec': 0.13154315948486328,
#   'found_body': True,
#   'found_face': False},
#  146: {'coords_list': [],
#   'sec': 0.12076735496520996,
#   'found_body': True,
#   'found_face': False},
#  147: {'coords_list': [],
#   'sec': 0.12993741035461426,
#   'found_body': True,
#   'found_face': False},
#  148: {'coords_list': [],
#   'sec': 0.13380050659179688,
#   'found_body': True,
#   'found_face': False},
#  149: {'coords_list': [],
#   'sec': 0.12358927726745605,
#   'found_body': True,
#   'found_face': False},
#  150: {'coords_list': [],
#   'sec': 0.13213849067687988,
#   'found_body': True,
#   'found_face': False},
#  151: {'coords_list': [],
#   'sec': 0.1399838924407959,
#   'found_body': True,
#   'found_face': False},
#  152: {'coords_list': [],
#   'sec': 0.1464371681213379,
#   'found_body': True,
#   'found_face': False},
#  153: {'coords_list': [],
#   'sec': 0.14012742042541504,
#   'found_body': True,
#   'found_face': False},
#  154: {'coords_list': [],
#   'sec': 0.12790584564208984,
#   'found_body': True,
#   'found_face': False},
#  155: {'coords_list': [(469, 227, 495, 253)],
#   'sec': 0.12394332885742188,
#   'found_body': True,
#   'found_face': True},
#  156: {'coords_list': [(469, 228, 495, 254)],
#   'sec': 0.12258481979370117,
#   'found_body': True,
#   'found_face': True},
#  157: {'coords_list': [(472, 229, 498, 255)],
#   'sec': 0.1351795196533203,
#   'found_body': True,
#   'found_face': True},
#  158: {'coords_list': [(472, 229, 497, 254)],
#   'sec': 0.13130545616149902,
#   'found_body': True,
#   'found_face': True},
#  159: {'coords_list': [(473, 231, 499, 257)],
#   'sec': 0.12279796600341797,
#   'found_body': True,
#   'found_face': True},
#  160: {'coords_list': [(473, 231, 499, 257)],
#   'sec': 0.12506365776062012,
#   'found_body': True,
#   'found_face': True},
#  161: {'coords_list': [],
#   'sec': 0.13100814819335938,
#   'found_body': True,
#   'found_face': False},
#  162: {'coords_list': [(479, 234, 507, 262)],
#   'sec': 0.14833402633666992,
#   'found_body': True,
#   'found_face': True},
#  163: {'coords_list': [(479, 234, 507, 262)],
#   'sec': 0.12804675102233887,
#   'found_body': True,
#   'found_face': True},
#  164: {'coords_list': [],
#   'sec': 0.1466844081878662,
#   'found_body': True,
#   'found_face': False},
#  165: {'coords_list': [],
#   'sec': 0.1225135326385498,
#   'found_body': True,
#   'found_face': False},
#  166: {'coords_list': [],
#   'sec': 0.12693166732788086,
#   'found_body': True,
#   'found_face': False},
#  167: {'coords_list': [],
#   'sec': 0.12993311882019043,
#   'found_body': True,
#   'found_face': False},
#  168: {'coords_list': [],
#   'sec': 0.13788723945617676,
#   'found_body': True,
#   'found_face': False},
#  169: {'coords_list': [],
#   'sec': 0.1253504753112793,
#   'found_body': True,
#   'found_face': False},
#  170: {'coords_list': [(486, 233, 513, 260)],
#   'sec': 0.12702631950378418,
#   'found_body': True,
#   'found_face': True},
#  171: {'coords_list': [(488, 234, 516, 262)],
#   'sec': 0.14430642127990723,
#   'found_body': True,
#   'found_face': True},
#  172: {'coords_list': [(487, 234, 515, 262)],
#   'sec': 0.12574386596679688,
#   'found_body': True,
#   'found_face': True},
#  173: {'coords_list': [],
#   'sec': 0.12142014503479004,
#   'found_body': True,
#   'found_face': False},
#  174: {'coords_list': [(490, 239, 517, 266)],
#   'sec': 0.11879086494445801,
#   'found_body': True,
#   'found_face': True},
#  175: {'coords_list': [(488, 238, 517, 267)],
#   'sec': 0.12056112289428711,
#   'found_body': True,
#   'found_face': True},
#  176: {'coords_list': [],
#   'sec': 0.15157508850097656,
#   'found_body': True,
#   'found_face': False},
#  177: {'coords_list': [],
#   'sec': 0.1456000804901123,
#   'found_body': True,
#   'found_face': False},
#  178: {'coords_list': [],
#   'sec': 0.15136075019836426,
#   'found_body': True,
#   'found_face': False},
#  179: {'coords_list': [(491, 240, 518, 267)],
#   'sec': 0.15137338638305664,
#   'found_body': True,
#   'found_face': True},
#  180: {'coords_list': [],
#   'sec': 0.14724946022033691,
#   'found_body': True,
#   'found_face': False},
#  181: {'coords_list': [],
#   'sec': 0.1516859531402588,
#   'found_body': True,
#   'found_face': False},
#  182: {'coords_list': [(493, 239, 520, 266)],
#   'sec': 0.14515900611877441,
#   'found_body': True,
#   'found_face': True},
#  183: {'coords_list': [(493, 239, 522, 268)],
#   'sec': 0.1567845344543457,
#   'found_body': True,
#   'found_face': True},
#  184: {'coords_list': [],
#   'sec': 0.15932464599609375,
#   'found_body': True,
#   'found_face': False},
#  185: {'coords_list': [],
#   'sec': 0.160355806350708,
#   'found_body': True,
#   'found_face': False},
#  186: {'coords_list': [(496, 239, 526, 269)],
#   'sec': 0.18950390815734863,
#   'found_body': True,
#   'found_face': True},
#  187: {'coords_list': [(496, 238, 527, 269)],
#   'sec': 0.15729880332946777,
#   'found_body': True,
#   'found_face': True},
#  188: {'coords_list': [(496, 238, 527, 269)],
#   'sec': 0.15848970413208008,
#   'found_body': True,
#   'found_face': True},
#  189: {'coords_list': [(496, 238, 527, 269)],
#   'sec': 0.15964722633361816,
#   'found_body': True,
#   'found_face': True},
#  190: {'coords_list': [(499, 243, 531, 275)],
#   'sec': 0.1658487319946289,
#   'found_body': True,
#   'found_face': True},
#  191: {'coords_list': [(501, 246, 531, 276)],
#   'sec': 0.15656709671020508,
#   'found_body': True,
#   'found_face': True},
#  192: {'coords_list': [(506, 250, 534, 278)],
#   'sec': 0.18216729164123535,
#   'found_body': True,
#   'found_face': True},
#  193: {'coords_list': [(504, 250, 534, 280)],
#   'sec': 0.17125678062438965,
#   'found_body': True,
#   'found_face': True},
#  194: {'coords_list': [(506, 251, 536, 281)],
#   'sec': 0.14802002906799316,
#   'found_body': True,
#   'found_face': True},
#  195: {'coords_list': [(510, 251, 540, 281)],
#   'sec': 0.15575313568115234,
#   'found_body': True,
#   'found_face': True},
#  196: {'coords_list': [],
#   'sec': 0.1325206756591797,
#   'found_body': True,
#   'found_face': False},
#  197: {'coords_list': [(510, 249, 542, 281)],
#   'sec': 0.16279315948486328,
#   'found_body': True,
#   'found_face': True},
#  198: {'coords_list': [(513, 249, 543, 279)],
#   'sec': 0.1496284008026123,
#   'found_body': True,
#   'found_face': True},
#  199: {'coords_list': [(512, 248, 544, 280), (461, 223, 558, 320)],
#   'sec': 0.1444110870361328,
#   'found_body': True,
#   'found_face': True},
#  200: {'coords_list': [(513, 247, 546, 280)],
#   'sec': 0.15056228637695312,
#   'found_body': True,
#   'found_face': True},
#  201: {'coords_list': [(515, 250, 544, 279)],
#   'sec': 0.15754461288452148,
#   'found_body': True,
#   'found_face': True},
#  202: {'coords_list': [],
#   'sec': 0.16614627838134766,
#   'found_body': True,
#   'found_face': False},
#  203: {'coords_list': [],
#   'sec': 0.1611778736114502,
#   'found_body': True,
#   'found_face': False},
#  204: {'coords_list': [],
#   'sec': 0.1502692699432373,
#   'found_body': True,
#   'found_face': False},
#  205: {'coords_list': [],
#   'sec': 0.13214969635009766,
#   'found_body': True,
#   'found_face': False},
#  206: {'coords_list': [],
#   'sec': 0.14866280555725098,
#   'found_body': True,
#   'found_face': False},
#  207: {'coords_list': [(510, 257, 546, 293)],
#   'sec': 0.14931058883666992,
#   'found_body': True,
#   'found_face': True},
#  208: {'coords_list': [],
#   'sec': 0.13319182395935059,
#   'found_body': True,
#   'found_face': False},
#  209: {'coords_list': [(511, 261, 544, 294)],
#   'sec': 0.14973902702331543,
#   'found_body': True,
#   'found_face': True},
#  210: {'coords_list': [(507, 261, 543, 297)],
#   'sec': 0.1450958251953125,
#   'found_body': True,
#   'found_face': True},
#  211: {'coords_list': [(508, 261, 543, 296)],
#   'sec': 0.14741110801696777,
#   'found_body': True,
#   'found_face': True},
#  212: {'coords_list': [(507, 262, 540, 295)],
#   'sec': 0.14266204833984375,
#   'found_body': True,
#   'found_face': True},
#  213: {'coords_list': [],
#   'sec': 0.13632965087890625,
#   'found_body': True,
#   'found_face': False},
#  214: {'coords_list': [],
#   'sec': 0.1272590160369873,
#   'found_body': True,
#   'found_face': False},
#  215: {'coords_list': [],
#   'sec': 0.13402295112609863,
#   'found_body': True,
#   'found_face': False},
#  216: {'coords_list': [],
#   'sec': 0.15796256065368652,
#   'found_body': True,
#   'found_face': False},
#  217: {'coords_list': [],
#   'sec': 0.14584636688232422,
#   'found_body': True,
#   'found_face': False},
#  218: {'coords_list': [],
#   'sec': 0.18614840507507324,
#   'found_body': True,
#   'found_face': False},
#  219: {'coords_list': [],
#   'sec': 0.1570277214050293,
#   'found_body': True,
#   'found_face': False},
#  220: {'coords_list': [(501, 261, 538, 298)],
#   'sec': 0.1518840789794922,
#   'found_body': True,
#   'found_face': True},
#  221: {'coords_list': [(500, 262, 540, 302)],
#   'sec': 0.15663480758666992,
#   'found_body': True,
#   'found_face': True},
#  222: {'coords_list': [(497, 267, 541, 311)],
#   'sec': 0.15308213233947754,
#   'found_body': True,
#   'found_face': True},
#  223: {'coords_list': [],
#   'sec': 0.14487862586975098,
#   'found_body': True,
#   'found_face': False},
#  224: {'coords_list': [(494, 268, 542, 316)],
#   'sec': 0.15186095237731934,
#   'found_body': True,
#   'found_face': True},
#  225: {'coords_list': [(495, 275, 540, 320)],
#   'sec': 0.12830448150634766,
#   'found_body': True,
#   'found_face': True},
#  226: {'coords_list': [(494, 275, 540, 321)],
#   'sec': 0.1358625888824463,
#   'found_body': True,
#   'found_face': True},
#  227: {'coords_list': [(495, 276, 541, 322)],
#   'sec': 0.15487909317016602,
#   'found_body': True,
#   'found_face': True},
#  228: {'coords_list': [(494, 277, 539, 322)],
#   'sec': 0.13145804405212402,
#   'found_body': True,
#   'found_face': True},
#  229: {'coords_list': [(496, 277, 540, 321)],
#   'sec': 0.1459946632385254,
#   'found_body': True,
#   'found_face': True},
#  230: {'coords_list': [(494, 278, 539, 323)],
#   'sec': 0.14686250686645508,
#   'found_body': True,
#   'found_face': True},
#  231: {'coords_list': [],
#   'sec': 0.1304173469543457,
#   'found_body': True,
#   'found_face': False},
#  232: {'coords_list': [(490, 277, 538, 325)],
#   'sec': 0.13516926765441895,
#   'found_body': True,
#   'found_face': True},
#  233: {'coords_list': [],
#   'sec': 0.14210152626037598,
#   'found_body': True,
#   'found_face': False},
#  234: {'coords_list': [],
#   'sec': 0.16186141967773438,
#   'found_body': True,
#   'found_face': False},
#  235: {'coords_list': [(481, 281, 530, 330)],
#   'sec': 0.15106487274169922,
#   'found_body': True,
#   'found_face': True},
#  236: {'coords_list': [(478, 282, 529, 333)],
#   'sec': 0.17632126808166504,
#   'found_body': True,
#   'found_face': True},
#  237: {'coords_list': [(470, 289, 522, 341)],
#   'sec': 0.16944289207458496,
#   'found_body': True,
#   'found_face': True},
#  238: {'coords_list': [(469, 287, 524, 342)],
#   'sec': 0.17370390892028809,
#   'found_body': True,
#   'found_face': True},
#  239: {'coords_list': [(465, 292, 520, 347)],
#   'sec': 0.162797212600708,
#   'found_body': True,
#   'found_face': True},
#  240: {'coords_list': [(457, 298, 513, 354)],
#   'sec': 0.1651163101196289,
#   'found_body': True,
#   'found_face': True},
#  241: {'coords_list': [(458, 298, 513, 353)],
#   'sec': 0.1706235408782959,
#   'found_body': True,
#   'found_face': True},
#  242: {'coords_list': [(453, 301, 510, 358)],
#   'sec': 0.16113495826721191,
#   'found_body': True,
#   'found_face': True},
#  243: {'coords_list': [(452, 301, 508, 357)],
#   'sec': 0.14598679542541504,
#   'found_body': True,
#   'found_face': True},
#  244: {'coords_list': [(444, 305, 499, 360)],
#   'sec': 0.14920830726623535,
#   'found_body': True,
#   'found_face': True},
#  245: {'coords_list': [(432, 306, 491, 365)],
#   'sec': 0.14722728729248047,
#   'found_body': True,
#   'found_face': True},
#  246: {'coords_list': [(433, 308, 490, 365)],
#   'sec': 0.15601539611816406,
#   'found_body': True,
#   'found_face': True},
#  247: {'coords_list': [(428, 308, 486, 366)],
#   'sec': 0.17113304138183594,
#   'found_body': True,
#   'found_face': True},
#  248: {'coords_list': [(427, 307, 485, 365)],
#   'sec': 0.1812303066253662,
#   'found_body': True,
#   'found_face': True},
#  249: {'coords_list': [(419, 310, 477, 368)],
#   'sec': 0.1654810905456543,
#   'found_body': True,
#   'found_face': True},
#  250: {'coords_list': [(415, 312, 473, 370)],
#   'sec': 0.15958166122436523,
#   'found_body': True,
#   'found_face': True},
#  251: {'coords_list': [(416, 311, 474, 369)],
#   'sec': 0.15577363967895508,
#   'found_body': True,
#   'found_face': True},
#  252: {'coords_list': [(415, 312, 473, 370)],
#   'sec': 0.15534043312072754,
#   'found_body': True,
#   'found_face': True},
#  253: {'coords_list': [(407, 318, 467, 378)],
#   'sec': 0.17899847030639648,
#   'found_body': True,
#   'found_face': True},
#  254: {'coords_list': [(396, 333, 458, 395)],
#   'sec': 0.16571283340454102,
#   'found_body': True,
#   'found_face': True},
#  255: {'coords_list': [(396, 333, 458, 395)],
#   'sec': 0.17486000061035156,
#   'found_body': True,
#   'found_face': True},
#  256: {'coords_list': [(392, 339, 454, 401), (364, 261, 600, 497)],
#   'sec': 0.18629097938537598,
#   'found_body': True,
#   'found_face': True},
#  257: {'coords_list': [(392, 339, 454, 401), (364, 261, 600, 497)],
#   'sec': 0.13771963119506836,
#   'found_body': False,
#   'found_face': True},
#  258: {'coords_list': [(392, 339, 454, 401), (364, 261, 600, 497)],
#   'sec': 0.13916659355163574,
#   'found_body': False,
#   'found_face': True},
#  259: {'coords_list': [(392, 339, 454, 401), (364, 261, 600, 497)],
#   'sec': 0.11725950241088867,
#   'found_body': False,
#   'found_face': True},
#  260: {'coords_list': [(392, 339, 454, 401), (364, 261, 600, 497)],
#   'sec': 0.12099099159240723,
#   'found_body': False,
#   'found_face': True},
#  261: {'coords_list': [(392, 339, 454, 401), (364, 261, 600, 497)],
#   'sec': 0.10928463935852051,
#   'found_body': False,
#   'found_face': True},
#  262: {'coords_list': [(392, 339, 454, 401), (364, 261, 600, 497)],
#   'sec': 0.10978841781616211,
#   'found_body': False,
#   'found_face': True},
#  263: {'coords_list': [],
#   'sec': 0.12973308563232422,
#   'found_body': True,
#   'found_face': False},
#  264: {'coords_list': [],
#   'sec': 0.1415705680847168,
#   'found_body': True,
#   'found_face': False},
#  265: {'coords_list': [],
#   'sec': 0.14448213577270508,
#   'found_body': False,
#   'found_face': False},
#  266: {'coords_list': [],
#   'sec': 0.15475749969482422,
#   'found_body': True,
#   'found_face': False},
#  267: {'coords_list': [],
#   'sec': 0.15303587913513184,
#   'found_body': True,
#   'found_face': False},
#  268: {'coords_list': [],
#   'sec': 0.14536213874816895,
#   'found_body': True,
#   'found_face': False},
#  269: {'coords_list': [],
#   'sec': 0.11408114433288574,
#   'found_body': True,
#   'found_face': False},
#  270: {'coords_list': [],
#   'sec': 0.1211552619934082,
#   'found_body': True,
#   'found_face': False},
#  271: {'coords_list': [],
#   'sec': 0.1170506477355957,
#   'found_body': True,
#   'found_face': False},
#  272: {'coords_list': [],
#   'sec': 0.11158323287963867,
#   'found_body': False,
#   'found_face': False},
#  273: {'coords_list': [],
#   'sec': 0.11348700523376465,
#   'found_body': False,
#   'found_face': False},
#  274: {'coords_list': [],
#   'sec': 0.11674237251281738,
#   'found_body': True,
#   'found_face': False},
#  275: {'coords_list': [],
#   'sec': 0.11689615249633789,
#   'found_body': True,
#   'found_face': False},
#  276: {'coords_list': [],
#   'sec': 0.11537337303161621,
#   'found_body': True,
#   'found_face': False},
#  277: {'coords_list': [],
#   'sec': 0.11768960952758789,
#   'found_body': True,
#   'found_face': False},
#  278: {'coords_list': [],
#   'sec': 0.13408374786376953,
#   'found_body': True,
#   'found_face': False},
#  279: {'coords_list': [],
#   'sec': 0.11519122123718262,
#   'found_body': True,
#   'found_face': False},
#  280: {'coords_list': [],
#   'sec': 0.13650298118591309,
#   'found_body': True,
#   'found_face': False},
#  281: {'coords_list': [],
#   'sec': 0.13652467727661133,
#   'found_body': True,
#   'found_face': False},
#  282: {'coords_list': [],
#   'sec': 0.11525177955627441,
#   'found_body': False,
#   'found_face': False},
#  283: {'coords_list': [],
#   'sec': 0.10958552360534668,
#   'found_body': False,
#   'found_face': False},
#  284: {'coords_list': [],
#   'sec': 0.1328434944152832,
#   'found_body': False,
#   'found_face': False},
#  285: {'coords_list': [],
#   'sec': 0.12972450256347656,
#   'found_body': False,
#   'found_face': False},
#  286: {'coords_list': [],
#   'sec': 0.11812305450439453,
#   'found_body': False,
#   'found_face': False},
#  287: {'coords_list': [],
#   'sec': 0.13280558586120605,
#   'found_body': False,
#   'found_face': False},
#  288: {'coords_list': [],
#   'sec': 0.1293935775756836,
#   'found_body': False,
#   'found_face': False},
#  289: {'coords_list': [],
#   'sec': 0.13448858261108398,
#   'found_body': False,
#   'found_face': False},
#  290: {'coords_list': [],
#   'sec': 0.1269993782043457,
#   'found_body': False,
#   'found_face': False},
#  291: {'coords_list': [],
#   'sec': 0.11911559104919434,
#   'found_body': False,
#   'found_face': False},
#  292: {'coords_list': [],
#   'sec': 0.1178274154663086,
#   'found_body': False,
#   'found_face': False},
#  293: {'coords_list': [],
#   'sec': 0.12959837913513184,
#   'found_body': False,
#   'found_face': False},
#  294: {'coords_list': [],
#   'sec': 0.11175107955932617,
#   'found_body': False,
#   'found_face': False},
#  295: {'coords_list': [],
#   'sec': 0.14967870712280273,
#   'found_body': False,
#   'found_face': False},
#  296: {'coords_list': [],
#   'sec': 0.15288162231445312,
#   'found_body': False,
#   'found_face': False},
#  297: {'coords_list': [],
#   'sec': 0.11632227897644043,
#   'found_body': True,
#   'found_face': False},
#  298: {'coords_list': [],
#   'sec': 0.11321163177490234,
#   'found_body': False,
#   'found_face': False},
#  299: {'coords_list': [],
#   'sec': 0.11382007598876953,
#   'found_body': False,
#   'found_face': False},
#  300: {'coords_list': [],
#   'sec': 0.11128497123718262,
#   'found_body': False,
#   'found_face': False},
#  301: {'coords_list': [],
#   'sec': 0.11013364791870117,
#   'found_body': False,
#   'found_face': False},
#  302: {'coords_list': [],
#   'sec': 0.12372040748596191,
#   'found_body': False,
#   'found_face': False},
#  303: {'coords_list': [],
#   'sec': 0.10901379585266113,
#   'found_body': False,
#   'found_face': False},
#  304: {'coords_list': [],
#   'sec': 0.11989378929138184,
#   'found_body': False,
#   'found_face': False},
#  305: {'coords_list': [],
#   'sec': 0.1491985321044922,
#   'found_body': True,
#   'found_face': False},
#  306: {'coords_list': [],
#   'sec': 0.14235234260559082,
#   'found_body': True,
#   'found_face': False},
#  307: {'coords_list': [],
#   'sec': 0.13149070739746094,
#   'found_body': True,
#   'found_face': False},
#  308: {'coords_list': [],
#   'sec': 0.11566448211669922,
#   'found_body': False,
#   'found_face': False},
#  309: {'coords_list': [],
#   'sec': 0.11254620552062988,
#   'found_body': False,
#   'found_face': False},
#  310: {'coords_list': [],
#   'sec': 0.11375045776367188,
#   'found_body': False,
#   'found_face': False},
#  311: {'coords_list': [],
#   'sec': 0.12267374992370605,
#   'found_body': False,
#   'found_face': False},
#  312: {'coords_list': [],
#   'sec': 0.1481609344482422,
#   'found_body': False,
#   'found_face': False},
#  313: {'coords_list': [],
#   'sec': 0.1403517723083496,
#   'found_body': False,
#   'found_face': False},
#  314: {'coords_list': [],
#   'sec': 0.1146240234375,
#   'found_body': False,
#   'found_face': False},
#  315: {'coords_list': [],
#   'sec': 0.11312031745910645,
#   'found_body': False,
#   'found_face': False},
#  316: {'coords_list': [],
#   'sec': 0.11412405967712402,
#   'found_body': False,
#   'found_face': False},
#  317: {'coords_list': [],
#   'sec': 0.11331343650817871,
#   'found_body': False,
#   'found_face': False},
#  318: {'coords_list': [],
#   'sec': 0.11704277992248535,
#   'found_body': False,
#   'found_face': False},
#  319: {'coords_list': [],
#   'sec': 0.11390113830566406,
#   'found_body': False,
#   'found_face': False},
#  320: {'coords_list': [],
#   'sec': 0.11731576919555664,
#   'found_body': False,
#   'found_face': False},
#  321: {'coords_list': [],
#   'sec': 0.14617514610290527,
#   'found_body': True,
#   'found_face': False},
#  322: {'coords_list': [],
#   'sec': 0.11845254898071289,
#   'found_body': False,
#   'found_face': False},
#  323: {'coords_list': [],
#   'sec': 0.11658906936645508,
#   'found_body': False,
#   'found_face': False},
#  324: {'coords_list': [],
#   'sec': 0.11360526084899902,
#   'found_body': False,
#   'found_face': False},
#  325: {'coords_list': [],
#   'sec': 0.12881159782409668,
#   'found_body': False,
#   'found_face': False},
#  326: {'coords_list': [],
#   'sec': 0.13047266006469727,
#   'found_body': False,
#   'found_face': False},
#  327: {'coords_list': [],
#   'sec': 0.14846444129943848,
#   'found_body': False,
#   'found_face': False},
#  328: {'coords_list': [],
#   'sec': 0.13835477828979492,
#   'found_body': True,
#   'found_face': False},
#  329: {'coords_list': [],
#   'sec': 0.1418306827545166,
#   'found_body': True,
#   'found_face': False},
#  330: {'coords_list': [],
#   'sec': 0.1538529396057129,
#   'found_body': False,
#   'found_face': False},
#  331: {'coords_list': [],
#   'sec': 0.14575552940368652,
#   'found_body': False,
#   'found_face': False},
#  332: {'coords_list': [],
#   'sec': 0.15811634063720703,
#   'found_body': True,
#   'found_face': False},
#  333: {'coords_list': [],
#   'sec': 0.14905905723571777,
#   'found_body': True,
#   'found_face': False},
#  334: {'coords_list': [],
#   'sec': 0.1333918571472168,
#   'found_body': False,
#   'found_face': False},
#  335: {'coords_list': [],
#   'sec': 0.14678335189819336,
#   'found_body': False,
#   'found_face': False},
#  336: {'coords_list': [],
#   'sec': 0.13469362258911133,
#   'found_body': False,
#   'found_face': False},
#  337: {'coords_list': [],
#   'sec': 0.14171266555786133,
#   'found_body': False,
#   'found_face': False},
#  338: {'coords_list': [],
#   'sec': 0.15146350860595703,
#   'found_body': False,
#   'found_face': False},
#  339: {'coords_list': [],
#   'sec': 0.14593935012817383,
#   'found_body': False,
#   'found_face': False},
#  340: {'coords_list': [],
#   'sec': 0.15376687049865723,
#   'found_body': False,
#   'found_face': False},
#  341: {'coords_list': [],
#   'sec': 0.15509772300720215,
#   'found_body': True,
#   'found_face': False},
#  342: {'coords_list': [],
#   'sec': 0.13628745079040527,
#   'found_body': True,
#   'found_face': False},
#  343: {'coords_list': [],
#   'sec': 0.1447310447692871,
#   'found_body': False,
#   'found_face': False},
#  344: {'coords_list': [],
#   'sec': 0.13446474075317383,
#   'found_body': False,
#   'found_face': False},
#  345: {'coords_list': [],
#   'sec': 0.1291046142578125,
#   'found_body': False,
#   'found_face': False},
#  346: {'coords_list': [],
#   'sec': 0.1381387710571289,
#   'found_body': False,
#   'found_face': False},
#  347: {'coords_list': [],
#   'sec': 0.11571788787841797,
#   'found_body': False,
#   'found_face': False},
#  348: {'coords_list': [],
#   'sec': 0.11431145668029785,
#   'found_body': False,
#   'found_face': False},
#  349: {'coords_list': [],
#   'sec': 0.12436914443969727,
#   'found_body': False,
#   'found_face': False},
#  350: {'coords_list': [],
#   'sec': 0.11477422714233398,
#   'found_body': False,
#   'found_face': False},
#  351: {'coords_list': [],
#   'sec': 0.1138315200805664,
#   'found_body': False,
#   'found_face': False},
#  352: {'coords_list': [],
#   'sec': 0.11929535865783691,
#   'found_body': False,
#   'found_face': False},
#  353: {'coords_list': [],
#   'sec': 0.13974428176879883,
#   'found_body': False,
#   'found_face': False},
#  354: {'coords_list': [],
#   'sec': 0.13958215713500977,
#   'found_body': False,
#   'found_face': False},
#  355: {'coords_list': [],
#   'sec': 0.13269996643066406,
#   'found_body': False,
#   'found_face': False},
#  356: {'coords_list': [],
#   'sec': 0.1262187957763672,
#   'found_body': False,
#   'found_face': False},
#  357: {'coords_list': [],
#   'sec': 0.11982059478759766,
#   'found_body': False,
#   'found_face': False},
#  358: {'coords_list': [],
#   'sec': 0.13335967063903809,
#   'found_body': False,
#   'found_face': False},
#  359: {'coords_list': [],
#   'sec': 0.11743378639221191,
#   'found_body': False,
#   'found_face': False},
#  360: {'coords_list': [],
#   'sec': 0.11903572082519531,
#   'found_body': False,
#   'found_face': False},
#  361: {'coords_list': [],
#   'sec': 0.13245296478271484,
#   'found_body': False,
#   'found_face': False},
#  362: {'coords_list': [],
#   'sec': 0.14412188529968262,
#   'found_body': False,
#   'found_face': False},
#  363: {'coords_list': [],
#   'sec': 0.13710618019104004,
#   'found_body': False,
#   'found_face': False},
#  364: {'coords_list': [],
#   'sec': 0.13934826850891113,
#   'found_body': True,
#   'found_face': False},
#  365: {'coords_list': [],
#   'sec': 0.11952829360961914,
#   'found_body': True,
#   'found_face': False},
#  366: {'coords_list': [],
#   'sec': 0.12318849563598633,
#   'found_body': True,
#   'found_face': False},
#  367: {'coords_list': [],
#   'sec': 0.11545801162719727,
#   'found_body': False,
#   'found_face': False},
#  368: {'coords_list': [],
#   'sec': 0.12066960334777832,
#   'found_body': False,
#   'found_face': False},
#  369: {'coords_list': [],
#   'sec': 0.11791634559631348,
#   'found_body': False,
#   'found_face': False},
#  370: {'coords_list': [],
#   'sec': 0.11670255661010742,
#   'found_body': False,
#   'found_face': False},
#  371: {'coords_list': [],
#   'sec': 0.11280083656311035,
#   'found_body': False,
#   'found_face': False},
#  372: {'coords_list': [],
#   'sec': 0.12490558624267578,
#   'found_body': False,
#   'found_face': False},
#  373: {'coords_list': [],
#   'sec': 0.11088371276855469,
#   'found_body': False,
#   'found_face': False},
#  374: {'coords_list': [],
#   'sec': 0.1408078670501709,
#   'found_body': False,
#   'found_face': False},
#  375: {'coords_list': [],
#   'sec': 0.12154841423034668,
#   'found_body': False,
#   'found_face': False},
#  376: {'coords_list': [],
#   'sec': 0.11781120300292969,
#   'found_body': False,
#   'found_face': False},
#  377: {'coords_list': [],
#   'sec': 0.13215112686157227,
#   'found_body': False,
#   'found_face': False},
#  378: {'coords_list': [],
#   'sec': 0.11649370193481445,
#   'found_body': False,
#   'found_face': False},
#  379: {'coords_list': [],
#   'sec': 0.14277172088623047,
#   'found_body': False,
#   'found_face': False},
#  380: {'coords_list': [],
#   'sec': 0.13855504989624023,
#   'found_body': False,
#   'found_face': False},
#  381: {'coords_list': [],
#   'sec': 0.13597846031188965,
#   'found_body': False,
#   'found_face': False},
#  382: {'coords_list': [],
#   'sec': 0.1284334659576416,
#   'found_body': False,
#   'found_face': False},
#  383: {'coords_list': [],
#   'sec': 0.12021517753601074,
#   'found_body': False,
#   'found_face': False},
#  384: {'coords_list': [],
#   'sec': 0.1198124885559082,
#   'found_body': False,
#   'found_face': False},
#  385: {'coords_list': [],
#   'sec': 0.13300585746765137,
#   'found_body': False,
#   'found_face': False},
#  386: {'coords_list': [],
#   'sec': 0.13192510604858398,
#   'found_body': True,
#   'found_face': False},
#  387: {'coords_list': [],
#   'sec': 0.1374073028564453,
#   'found_body': True,
#   'found_face': False},
#  388: {'coords_list': [],
#   'sec': 0.13795709609985352,
#   'found_body': True,
#   'found_face': False},
#  389: {'coords_list': [],
#   'sec': 0.14452123641967773,
#   'found_body': True,
#   'found_face': False},
#  390: {'coords_list': [],
#   'sec': 0.14536333084106445,
#   'found_body': True,
#   'found_face': False},
#  391: {'coords_list': [],
#   'sec': 0.11899113655090332,
#   'found_body': True,
#   'found_face': False},
#  392: {'coords_list': [],
#   'sec': 0.12738919258117676,
#   'found_body': True,
#   'found_face': False},
#  393: {'coords_list': [],
#   'sec': 0.12819552421569824,
#   'found_body': True,
#   'found_face': False},
#  394: {'coords_list': [],
#   'sec': 0.11767292022705078,
#   'found_body': True,
#   'found_face': False},
#  395: {'coords_list': [],
#   'sec': 0.13199758529663086,
#   'found_body': True,
#   'found_face': False},
#  396: {'coords_list': [],
#   'sec': 0.12868022918701172,
#   'found_body': True,
#   'found_face': False},
#  397: {'coords_list': [],
#   'sec': 0.13309645652770996,
#   'found_body': True,
#   'found_face': False},
#  398: {'coords_list': [],
#   'sec': 0.12270236015319824,
#   'found_body': True,
#   'found_face': False},
#  399: {'coords_list': [],
#   'sec': 0.12012910842895508,
#   'found_body': True,
#   'found_face': False},
#  400: {'coords_list': [],
#   'sec': 0.11764669418334961,
#   'found_body': True,
#   'found_face': False},
#  401: {'coords_list': [],
#   'sec': 0.11775755882263184,
#   'found_body': False,
#   'found_face': False},
#  402: {'coords_list': [],
#   'sec': 0.11587905883789062,
#   'found_body': False,
#   'found_face': False},
#  403: {'coords_list': [],
#   'sec': 0.13119244575500488,
#   'found_body': False,
#   'found_face': False},
#  404: {'coords_list': [],
#   'sec': 0.12150049209594727,
#   'found_body': True,
#   'found_face': False},
#  405: {'coords_list': [],
#   'sec': 0.11841368675231934,
#   'found_body': False,
#   'found_face': False},
#  406: {'coords_list': [],
#   'sec': 0.11483263969421387,
#   'found_body': False,
#   'found_face': False},
#  407: {'coords_list': [],
#   'sec': 0.1199800968170166,
#   'found_body': False,
#   'found_face': False},
#  408: {'coords_list': [],
#   'sec': 0.12769675254821777,
#   'found_body': False,
#   'found_face': False},
#  409: {'coords_list': [],
#   'sec': 0.12540888786315918,
#   'found_body': False,
#   'found_face': False},
#  410: {'coords_list': [],
#   'sec': 0.11790204048156738,
#   'found_body': False,
#   'found_face': False},
#  411: {'coords_list': [],
#   'sec': 0.14568233489990234,
#   'found_body': False,
#   'found_face': False},
#  412: {'coords_list': [],
#   'sec': 0.12039422988891602,
#   'found_body': False,
#   'found_face': False},
#  413: {'coords_list': [],
#   'sec': 0.13484430313110352,
#   'found_body': False,
#   'found_face': False},
#  414: {'coords_list': [],
#   'sec': 0.14387249946594238,
#   'found_body': False,
#   'found_face': False},
#  415: {'coords_list': [],
#   'sec': 0.14158320426940918,
#   'found_body': False,
#   'found_face': False},
#  416: {'coords_list': [],
#   'sec': 0.14469647407531738,
#   'found_body': False,
#   'found_face': False},
#  417: {'coords_list': [],
#   'sec': 0.12565326690673828,
#   'found_body': False,
#   'found_face': False},
#  418: {'coords_list': [],
#   'sec': 0.13314533233642578,
#   'found_body': False,
#   'found_face': False},
#  419: {'coords_list': [],
#   'sec': 0.15210413932800293,
#   'found_body': False,
#   'found_face': False},
#  420: {'coords_list': [],
#   'sec': 0.13706660270690918,
#   'found_body': False,
#   'found_face': False},
#  421: {'coords_list': [],
#   'sec': 0.14728975296020508,
#   'found_body': False,
#   'found_face': False},
#  422: {'coords_list': [],
#   'sec': 0.15059304237365723,
#   'found_body': True,
#   'found_face': False},
#  423: {'coords_list': [],
#   'sec': 0.13404488563537598,
#   'found_body': True,
#   'found_face': False},
#  424: {'coords_list': [],
#   'sec': 0.13850831985473633,
#   'found_body': True,
#   'found_face': False},
#  425: {'coords_list': [],
#   'sec': 0.12834858894348145,
#   'found_body': True,
#   'found_face': False},
#  426: {'coords_list': [],
#   'sec': 0.1194620132446289,
#   'found_body': True,
#   'found_face': False},
#  427: {'coords_list': [],
#   'sec': 0.11878609657287598,
#   'found_body': False,
#   'found_face': False},
#  428: {'coords_list': [],
#   'sec': 0.12131595611572266,
#   'found_body': False,
#   'found_face': False},
#  429: {'coords_list': [],
#   'sec': 0.11507821083068848,
#   'found_body': False,
#   'found_face': False},
#  430: {'coords_list': [],
#   'sec': 0.11592555046081543,
#   'found_body': False,
#   'found_face': False},
#  431: {'coords_list': [],
#   'sec': 0.1385796070098877,
#   'found_body': False,
#   'found_face': False},
#  432: {'coords_list': [],
#   'sec': 0.12140250205993652,
#   'found_body': False,
#   'found_face': False},
#  433: {'coords_list': [],
#   'sec': 0.12630057334899902,
#   'found_body': False,
#   'found_face': False},
#  434: {'coords_list': [],
#   'sec': 0.13649511337280273,
#   'found_body': False,
#   'found_face': False},
#  435: {'coords_list': [],
#   'sec': 0.1390976905822754,
#   'found_body': False,
#   'found_face': False},
#  436: {'coords_list': [],
#   'sec': 0.15179800987243652,
#   'found_body': False,
#   'found_face': False},
#  437: {'coords_list': [],
#   'sec': 0.147324800491333,
#   'found_body': False,
#   'found_face': False},
#  438: {'coords_list': [],
#   'sec': 0.13105535507202148,
#   'found_body': False,
#   'found_face': False},
#  439: {'coords_list': [],
#   'sec': 0.1485002040863037,
#   'found_body': False,
#   'found_face': False},
#  440: {'coords_list': [],
#   'sec': 0.11859583854675293,
#   'found_body': False,
#   'found_face': False},
#  441: {'coords_list': [],
#   'sec': 0.12258028984069824,
#   'found_body': False,
#   'found_face': False},
#  442: {'coords_list': [],
#   'sec': 0.11733841896057129,
#   'found_body': False,
#   'found_face': False},
#  443: {'coords_list': [],
#   'sec': 0.12042427062988281,
#   'found_body': False,
#   'found_face': False},
#  444: {'coords_list': [],
#   'sec': 0.12662816047668457,
#   'found_body': False,
#   'found_face': False},
#  445: {'coords_list': [],
#   'sec': 0.14229989051818848,
#   'found_body': False,
#   'found_face': False},
#  446: {'coords_list': [],
#   'sec': 0.14231634140014648,
#   'found_body': False,
#   'found_face': False},
#  447: {'coords_list': [],
#   'sec': 0.13435149192810059,
#   'found_body': False,
#   'found_face': False},
#  448: {'coords_list': [],
#   'sec': 0.13037991523742676,
#   'found_body': False,
#   'found_face': False},
#  449: {'coords_list': [],
#   'sec': 0.1148231029510498,
#   'found_body': False,
#   'found_face': False},
#  450: {'coords_list': [],
#   'sec': 0.11917638778686523,
#   'found_body': False,
#   'found_face': False},
#  451: {'coords_list': [],
#   'sec': 0.11807894706726074,
#   'found_body': False,
#   'found_face': False},
#  452: {'coords_list': [],
#   'sec': 0.1242210865020752,
#   'found_body': True,
#   'found_face': False},
#  453: {'coords_list': [],
#   'sec': 0.12294793128967285,
#   'found_body': True,
#   'found_face': False},
#  454: {'coords_list': [],
#   'sec': 0.12981820106506348,
#   'found_body': True,
#   'found_face': False},
#  455: {'coords_list': [],
#   'sec': 0.12631821632385254,
# ...
#  865: {'coords_list': [],
#   'sec': 0.1693117618560791,
#   'found_body': True,
#   'found_face': False},
#  866: {'coords_list': [],
#   'sec': 0.15938520431518555,
#   'found_body': True,
#   'found_face': False},
#  867: {'coords_list': [(477, 211, 504, 238)],
#   'sec': 0.15373921394348145,
#   'found_body': True,
#   'found_face': True},
#  868: {'coords_list': [],
#   'sec': 0.16005873680114746,
#   'found_body': True,
#   'found_face': False},
#  869: {'coords_list': [],
#   'sec': 0.17247867584228516,
#   'found_body': True,
#   'found_face': False},
#  870: {'coords_list': [],
#   'sec': 0.15836143493652344,
#   'found_body': True,
#   'found_face': False},
#  871: {'coords_list': [],
#   'sec': 0.15638065338134766,
#   'found_body': True,
#   'found_face': False},
#  872: {'coords_list': [],
#   'sec': 0.15366363525390625,
#   'found_body': True,
#   'found_face': False},
#  873: {'coords_list': [],
#   'sec': 0.14352989196777344,
#   'found_body': True,
#   'found_face': False},
#  874: {'coords_list': [(485, 213, 513, 241)],
#   'sec': 0.1413099765777588,
#   'found_body': True,
#   'found_face': True},
#  875: {'coords_list': [(487, 216, 514, 243)],
#   'sec': 0.15393853187561035,
#   'found_body': True,
#   'found_face': True},
#  876: {'coords_list': [(487, 217, 513, 243)],
#   'sec': 0.14968204498291016,
#   'found_body': True,
#   'found_face': True},
#  877: {'coords_list': [(489, 218, 516, 245)],
#   'sec': 0.13882064819335938,
#   'found_body': True,
#   'found_face': True},
#  878: {'coords_list': [(491, 219, 518, 246)],
#   'sec': 0.12931585311889648,
#   'found_body': True,
#   'found_face': True},
#  879: {'coords_list': [(491, 219, 518, 246)],
#   'sec': 0.12443423271179199,
#   'found_body': True,
#   'found_face': True},
#  880: {'coords_list': [(493, 219, 520, 246)],
#   'sec': 0.1352825164794922,
#   'found_body': True,
#   'found_face': True},
#  881: {'coords_list': [(496, 218, 524, 246)],
#   'sec': 0.17023491859436035,
#   'found_body': True,
#   'found_face': True},
#  882: {'coords_list': [(495, 218, 523, 246)],
#   'sec': 0.12955236434936523,
#   'found_body': True,
#   'found_face': True},
#  883: {'coords_list': [(496, 217, 524, 245)],
#   'sec': 0.13442611694335938,
#   'found_body': True,
#   'found_face': True},
#  884: {'coords_list': [(498, 216, 526, 244)],
#   'sec': 0.12836503982543945,
#   'found_body': True,
#   'found_face': True},
#  885: {'coords_list': [(498, 216, 526, 244)],
#   'sec': 0.12787270545959473,
#   'found_body': True,
#   'found_face': True},
#  886: {'coords_list': [(497, 215, 526, 244)],
#   'sec': 0.13270854949951172,
#   'found_body': True,
#   'found_face': True},
#  887: {'coords_list': [],
#   'sec': 0.14736366271972656,
#   'found_body': True,
#   'found_face': False},
#  888: {'coords_list': [(497, 215, 527, 245)],
#   'sec': 0.14874505996704102,
#   'found_body': True,
#   'found_face': True},
#  889: {'coords_list': [(497, 217, 525, 245)],
#   'sec': 0.15780305862426758,
#   'found_body': True,
#   'found_face': True},
#  890: {'coords_list': [],
#   'sec': 0.1583695411682129,
#   'found_body': True,
#   'found_face': False},
#  891: {'coords_list': [],
#   'sec': 0.14806342124938965,
#   'found_body': True,
#   'found_face': False},
#  892: {'coords_list': [],
#   'sec': 0.14817500114440918,
#   'found_body': True,
#   'found_face': False},
#  893: {'coords_list': [(495, 219, 527, 251)],
#   'sec': 0.1317753791809082,
#   'found_body': True,
#   'found_face': True},
#  894: {'coords_list': [],
#   'sec': 0.13942575454711914,
#   'found_body': True,
#   'found_face': False},
#  895: {'coords_list': [],
#   'sec': 0.12826251983642578,
#   'found_body': True,
#   'found_face': False},
#  896: {'coords_list': [],
#   'sec': 0.13634943962097168,
#   'found_body': True,
#   'found_face': False},
#  897: {'coords_list': [],
#   'sec': 0.13198041915893555,
#   'found_body': True,
#   'found_face': False},
#  898: {'coords_list': [],
#   'sec': 0.13724732398986816,
#   'found_body': True,
#   'found_face': False},
#  899: {'coords_list': [],
#   'sec': 0.13500142097473145,
#   'found_body': True,
#   'found_face': False},
#  900: {'coords_list': [],
#   'sec': 0.13173270225524902,
#   'found_body': True,
#   'found_face': False},
#  901: {'coords_list': [],
#   'sec': 0.1579902172088623,
#   'found_body': True,
#   'found_face': False},
#  902: {'coords_list': [(492, 220, 526, 254)],
#   'sec': 0.1559770107269287,
#   'found_body': True,
#   'found_face': True},
#  903: {'coords_list': [(492, 220, 526, 254)],
#   'sec': 0.1534557342529297,
#   'found_body': True,
#   'found_face': True},
#  904: {'coords_list': [(493, 221, 526, 254)],
#   'sec': 0.16236662864685059,
#   'found_body': True,
#   'found_face': True},
#  905: {'coords_list': [(496, 223, 525, 252)],
#   'sec': 0.16599202156066895,
#   'found_body': True,
#   'found_face': True},
#  906: {'coords_list': [(495, 221, 526, 252)],
#   'sec': 0.16078519821166992,
#   'found_body': True,
#   'found_face': True},
#  907: {'coords_list': [],
#   'sec': 0.16406559944152832,
#   'found_body': True,
#   'found_face': False},
#  908: {'coords_list': [(496, 224, 529, 257)],
#   'sec': 0.16054940223693848,
#   'found_body': True,
#   'found_face': True},
#  909: {'coords_list': [(496, 224, 529, 257)],
#   'sec': 0.1605992317199707,
#   'found_body': True,
#   'found_face': True},
#  910: {'coords_list': [],
#   'sec': 0.16458916664123535,
#   'found_body': True,
#   'found_face': False},
#  911: {'coords_list': [(497, 230, 532, 265)],
#   'sec': 0.1638166904449463,
#   'found_body': True,
#   'found_face': True},
#  912: {'coords_list': [(497, 228, 536, 267)],
#   'sec': 0.19250011444091797,
#   'found_body': True,
#   'found_face': True},
#  913: {'coords_list': [],
#   'sec': 0.17504501342773438,
#   'found_body': True,
#   'found_face': False},
#  914: {'coords_list': [],
#   'sec': 0.16518235206604004,
#   'found_body': True,
#   'found_face': False},
#  915: {'coords_list': [(502, 232, 538, 268)],
#   'sec': 0.16578006744384766,
#   'found_body': True,
#   'found_face': True},
#  916: {'coords_list': [(505, 231, 542, 268)],
#   'sec': 0.16890883445739746,
#   'found_body': True,
#   'found_face': True},
#  917: {'coords_list': [],
#   'sec': 0.15768051147460938,
#   'found_body': True,
#   'found_face': False},
#  918: {'coords_list': [(505, 230, 541, 266)],
#   'sec': 0.1741008758544922,
#   'found_body': True,
#   'found_face': True},
#  919: {'coords_list': [(505, 228, 544, 267)],
#   'sec': 0.1436150074005127,
#   'found_body': True,
#   'found_face': True},
#  920: {'coords_list': [(505, 228, 544, 267)],
#   'sec': 0.14657187461853027,
#   'found_body': True,
#   'found_face': True},
#  921: {'coords_list': [(504, 228, 543, 267)],
#   'sec': 0.15717315673828125,
#   'found_body': True,
#   'found_face': True},
#  922: {'coords_list': [(504, 228, 544, 268)],
#   'sec': 0.14663958549499512,
#   'found_body': True,
#   'found_face': True},
#  923: {'coords_list': [(504, 229, 542, 267)],
#   'sec': 0.15879344940185547,
#   'found_body': True,
#   'found_face': True},
#  924: {'coords_list': [(503, 229, 543, 269)],
#   'sec': 0.1387038230895996,
#   'found_body': True,
#   'found_face': True},
#  925: {'coords_list': [(503, 229, 543, 269)],
#   'sec': 0.15424633026123047,
#   'found_body': True,
#   'found_face': True},
#  926: {'coords_list': [(502, 233, 541, 272), (450, 187, 557, 294)],
#   'sec': 0.14062213897705078,
#   'found_body': True,
#   'found_face': True},
#  927: {'coords_list': [(502, 234, 541, 273)],
#   'sec': 0.1480565071105957,
#   'found_body': True,
#   'found_face': True},
#  928: {'coords_list': [(501, 234, 541, 274)],
#   'sec': 0.1296682357788086,
#   'found_body': True,
#   'found_face': True},
#  929: {'coords_list': [(501, 235, 540, 274)],
#   'sec': 0.13678646087646484,
#   'found_body': True,
#   'found_face': True},
#  930: {'coords_list': [(499, 237, 542, 280)],
#   'sec': 0.1339268684387207,
#   'found_body': True,
#   'found_face': True},
#  931: {'coords_list': [(495, 241, 536, 282)],
#   'sec': 0.14060568809509277,
#   'found_body': True,
#   'found_face': True},
#  932: {'coords_list': [(492, 240, 536, 284)],
#   'sec': 0.14484906196594238,
#   'found_body': True,
#   'found_face': True},
#  933: {'coords_list': [(493, 241, 536, 284)],
#   'sec': 0.14569735527038574,
#   'found_body': True,
#   'found_face': True},
#  934: {'coords_list': [(489, 239, 534, 284)],
#   'sec': 0.15700364112854004,
#   'found_body': True,
#   'found_face': True},
#  935: {'coords_list': [(489, 239, 534, 284)],
#   'sec': 0.1539003849029541,
#   'found_body': True,
#   'found_face': True},
#  936: {'coords_list': [(489, 239, 534, 284)],
#   'sec': 0.11886906623840332,
#   'found_body': False,
#   'found_face': True},
#  937: {'coords_list': [(488, 237, 535, 284)],
#   'sec': 0.16666722297668457,
#   'found_body': True,
#   'found_face': True},
#  938: {'coords_list': [(489, 238, 534, 283)],
#   'sec': 0.17516708374023438,
#   'found_body': True,
#   'found_face': True},
#  939: {'coords_list': [(487, 237, 535, 285)],
#   'sec': 0.17542481422424316,
#   'found_body': True,
#   'found_face': True},
#  940: {'coords_list': [(488, 238, 537, 287)],
#   'sec': 0.14020228385925293,
#   'found_body': True,
#   'found_face': True},
#  941: {'coords_list': [(488, 237, 537, 286)],
#   'sec': 0.1485612392425537,
#   'found_body': True,
#   'found_face': True},
#  942: {'coords_list': [(487, 239, 538, 290)],
#   'sec': 0.16660165786743164,
#   'found_body': True,
#   'found_face': True},
#  943: {'coords_list': [(490, 245, 541, 296)],
#   'sec': 0.18236207962036133,
#   'found_body': True,
#   'found_face': True},
#  944: {'coords_list': [(490, 245, 541, 296)],
#   'sec': 0.1672801971435547,
#   'found_body': True,
#   'found_face': True},
#  945: {'coords_list': [(490, 248, 542, 300)],
#   'sec': 0.17814111709594727,
#   'found_body': True,
#   'found_face': True},
#  946: {'coords_list': [(493, 254, 546, 307)],
#   'sec': 0.17597723007202148,
#   'found_body': True,
#   'found_face': True},
#  947: {'coords_list': [(493, 254, 546, 307)],
#   'sec': 0.16181540489196777,
#   'found_body': True,
#   'found_face': True},
#  948: {'coords_list': [(493, 255, 548, 310)],
#   'sec': 0.17314386367797852,
#   'found_body': True,
#   'found_face': True},
#  949: {'coords_list': [(497, 258, 552, 313)],
#   'sec': 0.17883634567260742,
#   'found_body': True,
#   'found_face': True},
#  950: {'coords_list': [(496, 258, 551, 313)],
#   'sec': 0.1720600128173828,
#   'found_body': True,
#   'found_face': True},
#  951: {'coords_list': [(498, 259, 552, 313)],
#   'sec': 0.1680738925933838,
#   'found_body': True,
#   'found_face': True},
#  952: {'coords_list': [(499, 258, 555, 314)],
#   'sec': 0.1721057891845703,
#   'found_body': True,
#   'found_face': True},
#  953: {'coords_list': [(498, 257, 555, 314)],
#   'sec': 0.1661853790283203,
#   'found_body': True,
#   'found_face': True},
#  954: {'coords_list': [(499, 259, 554, 314)],
#   'sec': 0.17883777618408203,
#   'found_body': True,
#   'found_face': True},
#  955: {'coords_list': [(497, 258, 554, 315)],
#   'sec': 0.17268610000610352,
#   'found_body': True,
#   'found_face': True},
#  956: {'coords_list': [(497, 258, 553, 314)],
#   'sec': 0.1810762882232666,
#   'found_body': True,
#   'found_face': True},
#  957: {'coords_list': [(497, 258, 553, 314)],
#   'sec': 0.18317747116088867,
#   'found_body': True,
#   'found_face': True},
#  958: {'coords_list': [],
#   'sec': 0.14588284492492676,
#   'found_body': True,
#   'found_face': False},
#  959: {'coords_list': [(491, 261, 549, 319)],
#   'sec': 0.1873016357421875,
#   'found_body': True,
#   'found_face': True},
#  960: {'coords_list': [(490, 264, 547, 321)],
#   'sec': 0.15184783935546875,
#   'found_body': True,
#   'found_face': True},
#  961: {'coords_list': [(486, 270, 546, 330)],
#   'sec': 0.18881440162658691,
#   'found_body': True,
#   'found_face': True},
#  962: {'coords_list': [(481, 273, 545, 337)],
#   'sec': 0.18636536598205566,
#   'found_body': True,
#   'found_face': True},
#  963: {'coords_list': [(482, 272, 546, 336)],
#   'sec': 0.19643259048461914,
#   'found_body': True,
#   'found_face': True},
#  964: {'coords_list': [(477, 279, 543, 345)],
#   'sec': 0.17688632011413574,
#   'found_body': True,
#   'found_face': True},
#  965: {'coords_list': [(477, 280, 541, 344)],
#   'sec': 0.17220330238342285,
#   'found_body': True,
#   'found_face': True},
#  966: {'coords_list': [(475, 283, 539, 347)],
#   'sec': 0.17219066619873047,
#   'found_body': True,
#   'found_face': True},
#  967: {'coords_list': [(469, 285, 536, 352)],
#   'sec': 0.18590974807739258,
#   'found_body': True,
#   'found_face': True},
#  968: {'coords_list': [(469, 285, 536, 352)],
#   'sec': 0.13828587532043457,
#   'found_body': False,
#   'found_face': True},
#  969: {'coords_list': [(469, 285, 536, 352)],
#   'sec': 0.11368131637573242,
#   'found_body': False,
#   'found_face': True},
#  970: {'coords_list': [(463, 287, 530, 354)],
#   'sec': 0.1692965030670166,
#   'found_body': True,
#   'found_face': True},
#  971: {'coords_list': [(463, 287, 530, 354)],
#   'sec': 0.12085080146789551,
#   'found_body': False,
#   'found_face': True},
#  972: {'coords_list': [(463, 287, 530, 354)],
#   'sec': 0.12484169006347656,
#   'found_body': False,
#   'found_face': True},
#  973: {'coords_list': [(463, 287, 530, 354)],
#   'sec': 0.14740896224975586,
#   'found_body': False,
#   'found_face': True},
#  974: {'coords_list': [(457, 286, 531, 360)],
#   'sec': 0.18548154830932617,
#   'found_body': True,
#   'found_face': True},
#  975: {'coords_list': [(458, 286, 532, 360)],
#   'sec': 0.18862366676330566,
#   'found_body': True,
#   'found_face': True},
#  976: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.19039535522460938,
#   'found_body': True,
#   'found_face': True},
#  977: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1464252471923828,
#   'found_body': False,
#   'found_face': True},
#  978: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.14313745498657227,
#   'found_body': False,
#   'found_face': True},
#  979: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1412215232849121,
#   'found_body': False,
#   'found_face': True},
#  980: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.14179754257202148,
#   'found_body': False,
#   'found_face': True},
#  981: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.13562369346618652,
#   'found_body': False,
#   'found_face': True},
#  982: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.13546037673950195,
#   'found_body': False,
#   'found_face': True},
#  983: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.13976240158081055,
#   'found_body': False,
#   'found_face': True},
#  984: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.14623641967773438,
#   'found_body': False,
#   'found_face': True},
#  985: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.13576889038085938,
#   'found_body': False,
#   'found_face': True},
#  986: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.13787531852722168,
#   'found_body': False,
#   'found_face': True},
#  987: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1428225040435791,
#   'found_body': False,
#   'found_face': True},
#  988: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.14932036399841309,
#   'found_body': False,
#   'found_face': True},
#  989: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1516103744506836,
#   'found_body': False,
#   'found_face': True},
#  990: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1437370777130127,
#   'found_body': False,
#   'found_face': True},
#  991: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1394660472869873,
#   'found_body': False,
#   'found_face': True},
#  992: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1395108699798584,
#   'found_body': False,
#   'found_face': True},
#  993: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.12166714668273926,
#   'found_body': False,
#   'found_face': True},
#  994: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1158592700958252,
#   'found_body': False,
#   'found_face': True},
#  995: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.12604618072509766,
#   'found_body': False,
#   'found_face': True},
#  996: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.13969659805297852,
#   'found_body': False,
#   'found_face': True},
#  997: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1337733268737793,
#   'found_body': False,
#   'found_face': True},
#  998: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.12958765029907227,
#   'found_body': False,
#   'found_face': True},
#  999: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.13693690299987793,
#   'found_body': False,
#   'found_face': True},
#  1000: {'coords_list': [(455, 291, 535, 371)],
#   'sec': 0.1314854621887207,
#   'found_body': False,
#   'found_face': True},
#  ...}

# %%
true_list = []
for key, value in true_dict.items():
    true_list.append(value['sec'])
true_list = [1/item for item in true_list[1:]] # discard 1st frame for cold start latency

# %%
inferred_list = []
for key, value in inferred_dict.items():
    inferred_list.append(value['sec'])
inferred_list = [1/item for item in inferred_list[1:]] # discard 1st frame for cold start latency
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-334522564820> in <module>
#       2 for key, value in inferred_dict.items():
#       3     inferred_list.append(value['sec'])
# ----> 4 inferred_list = [1/item for item in infer_list[1:]] # discard 1st frame for cold start latency
#
# NameError: name 'infer_list' is not defined

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# %%
import pandas as pd

# %%
df = pd.DataFrame([true_list, infer_list]).transpose()
df.columns = ['true','inferred']
df.head()

# %%
data = [{
    'x': df.index,
    'y': df[col],
    'name': col
}  for col in df.columns]

# %%
layout = go.Layout(
    title='Face Extraction (true v. inferred)',
    yaxis=dict(       
        title='fps',
    ),
    xaxis=dict(
        title='frame number',
    )
)

# %%
fig = go.Figure(data=data, layout=layout)

# %%
# py.iplot(fig)

# %%
appearances = {}
f = open('clip-Appearances.txt','r')
for x in f:
    split = x.strip('\n').split(',')
    actor = int(split[0])
    appearances[actor] = [int(split[1]), int(split[2])]

# %%
appearances

# %%
# 'true' found

tp = 0 # face there, face detected
fn = 0 # face there, face not detected

for actor in appearances.keys():
    for fnum in range(appearances[0][0], appearances[0][1]):
        true_found = true_dict[fnum]['coords_list']
        if len(true_found)>0: # detected
            tp += 1
        else: # not detected
            fn += 1

# %%
tp, fn

# %%
tp / (tp+fn), fn / (tp+fn)

# %%
# 'infer' found

tp = 0 # face there, face detected
fn = 0 # face there, face not detected

fn_frames = []
for actor in appearances.keys():
    for fnum in range(appearances[actor][0], appearances[actor][1]):
        inferred_found = inferred_dict[fnum]['coords_list']
        if len(infer_found)>0: # detected
            tp += 1
        else: # not detected
            fn_frames.append(fnum)
            fn += 1

# %%
tp, fn

# %%
tp / (tp+fn), fn / (tp+fn)

# %% [markdown]
# This poor accuracy is due to the fact that sometimes the body detector fails, which means a face cannot be found. We can remedy this by using a more accurate body detector. Options: YOLOv3, etc.

# %%
# To confirm our suspicions, let's look at the false negatives reported by the inferred version.

# %%
no_body_no_face = 0 # want to minimize this
yes_body_no_face = 0 # want to minimize this

for fnum in fn_frames:
    body = infer_dict[fnum]['found_body']
    face = infer_dict[fnum]['found_face']
    
    if (not body) & (not face): no_body_no_face += 1
    else: yes_body_no_face += 1

# %%
no_body_no_face, yes_body_no_face

# %% [markdown]
# Ok, so the detector did not perform as poorly as I expected. I expected that there would be more instances of no_body_no_face. However, 54/255 = ~21% of the missed labels stem from the fact that a body could not be detected. It seems that both the face and body detectors need improvement.
